# %% [markdown]
# ## SOTA RAG with EquoAI!

# %%
# !pip install equoai 
! pip install PyPDF2
# !pip install sentence-transformers
# Out:
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: equoai in /home/dolan/anaconda3/lib/python3.9/site-packages (1.0.5)
# Requirement already satisfied: requests in /home/dolan/anaconda3/lib/python3.9/site-packages (from equoai) (2.32.3)
# Requirement already satisfied: numpy in /home/dolan/anaconda3/lib/python3.9/site-packages (from equoai) (1.26.4)
# Requirement already satisfied: tiktoken in /home/dolan/anaconda3/lib/python3.9/site-packages (from equoai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->equoai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->equoai) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->equoai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->equoai) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in /home/dolan/anaconda3/lib/python3.9/site-packages (from tiktoken->equoai) (2022.7.9)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: PyPDF2 in /home/dolan/anaconda3/lib/python3.9/site-packages (3.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from PyPDF2) (4.12.2)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: sentence-transformers in /home/dolan/anaconda3/lib/python3.9/site-packages (3.3.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.46.2)
# Requirement already satisfied: tqdm in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.11.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /home/dolan/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /home/dolan/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /home/dolan/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/dolan/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0)
# Requirement already satisfied: requests in /home/dolan/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dolan/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.8.4)
# Requirement already satisfied: jinja2 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/dolan/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.2.1)
# Requirement already satisfied: numpy>=1.17 in /home/dolan/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/dolan/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: safetensors>=0.4.1 in /home/dolan/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/dolan/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: joblib>=0.11 in /home/dolan/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/dolan/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dolan/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -otocore (/home/dolan/anaconda3/lib/python3.9/site-packages)

# %%
from equoai import equonode
from sentence_transformers import SentenceTransformer
import os 
import PyPDF2
import numpy as np
from ollama import Client
import sys
import requests

def query_with_ollama(prompt : str, is_verbose=True) -> str:
    '''Query function using Ollama proxy'''

    # client = Client(host=os.getenv("LOCAL_SERVER_URI"))
    client = Client(host="https://ollama.newatlantis.top")

    # client = Client(host="https://pop-os.tailcff25c.ts.net/abcdefghijk")

    stream = client.chat( 
        model = "llama3.2:latest",

        # model = "mistral:7b-instruct", #This has to be added to the hardware we're using.
        messages=[{'role': 'user', 'content': prompt}],
        stream=True,
    )
    completion=""
    try:
        for chunk in stream:
            if chunk is not None:
                if is_verbose is True:
                    print(chunk['message']['content'])
                completion += chunk['message']['content']
                sys.stdout.flush()
                if chunk['message']['content'] == "<|eot_id|>":
                    stream.close() #Close the stream?
                    print("Closing the stream.")

    except Exception as e:
        print(f"{e}") 

    # return request.data["message"
    return completion 


class RAGPipeline:
    
    def __init__(self, model_name="sentence-transformers/multi-qa-MiniLM-L6-cos-v1"):
        self.model = SentenceTransformer(model_name)
        self.documents = []
        self.context = []
        self.entity_index = []
        
    def cosine(self, u: np.ndarray, v: np.ndarray) -> float:
        """
        Cosine similarity metric
        """
        return u.dot(v) / np.sqrt(u.dot(u) * v.dot(v))
    
    def process(self, query: str, documents: list[str]) -> None:
        """
        Order pieces of context by relevance to the user's query
        """
        # Generate embeddings 
        x = self.model.encode(query)
        vectors = self.model.encode(documents)
        self.context = [{"text":doc, "score":self.cosine(vectors[i], x)} for i, doc in enumerate(documents)]
        self.context= sorted(self.context, key=lambda x: x["score"], reverse=True)
        
        
    def retrieve(self, k=10) -> str:
        """
        Retrieve top-K most relevant documents
        Format: 
        Article 1: blah blah blah 
        Article 2: ...
        Article 3: ...
        """
        return "document: ".join([f'{i}: {obj["text"]} 'for i, obj in enumerate(self.context)][:k])
    
    def run(self, query: str, documents: list[str], is_optimized=False) -> str:
        """
            Handle the entire RAG, end-to-end
        """
        pipeline.process(query, documents)
        context = pipeline.retrieve()

        return query_with_ollama(f"Article: {context} \n Answer the following question using the article provided: {query}",
                 is_verbose=False)

    
def parse_pdf(file_path):
    """
    Read the local PDF file
    """
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        
        # Iterate over all the pages and extract text
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
            
        return text
# Out:
# {'Roger': '<PERSON1>', 'Donald': '<PERSON2>', 'Acme Inc.': '<ORGANIZATION 1>', 'IBM': '<ORGANIZATION 2>'}
# Document: 2021
# ESG Data
# Supplement2021 ESG DATA SUPPLEMENT › P0WER CORPORATION OF CANADA2/22
# Social Environment Governance ESG Index 2021 ESG Data Supplement
# At Power Corporation, we are committed
# to continuously enhancing our
# Environmental, Social and Governance
# (ESG) reporting
# Document:
# This document provides quantitative
# information on our ESG achievements,
# and is intended to supplement
# the information available on our
# Sustainability website
# Document: Reporting Scope
# The content of this ESG data supplement has been
# informed by stakeholder requests, as well as international
# standards on ESG reporting, including the Global
# Reporting Initiative (GRI) Standards, Sustainability
# Accounting Standards Board (SASB), the World Economic
# Forum (WEF) “Measuring Stakeholder Capitalism: Towards
# Common Metrics and Consistent Reporting of Sustainable
# Value Creation”, and the Task Force on Climate-related
# Financial Disclosures (TCFD) Recommendations
# Document:  The
# data is reported annually, for the calendar years ended
# December 31, unless otherwise indicated
# Document:
# Environment: Our environmental data includes the data
# of our publicly traded operating companies Great-West
# Lifeco and IGM Financial, as well as that of our wholly
# owned subsidiary Square Victoria Real Estate
# Document:
# Social: Power Corporation’s employee data is consolidated
# based on the definition of financial control and therefore
# includes the data of our publicly traded operating companies
# Great -W est Lifeco and IGM Financial, as well as the data of
# the Corporation’s wholly owned or controlled subsidiaries
# Document:
# Governance: Our governance data pertains to
# Power Corporation
# Document: External Assessment
# We are committed to ensuring the quality and integrity
# of the data we report
# Document:  To date, our environmental
# data related to GHG emissions have been verified by
# PricewaterhouseCoopers (PwC) to a limited level of
# assurance in accordance with the International Standard
# on Assurance Engagements 3410, Assurance Engagements
# on Greenhouse Gas Statements (ISAE 3410)
# Document:
# Additional Information Sources
# For additional information, readers are referred
# to our Sustainability website where we publicly disclose
# our sustainability policies, commitments and initiatives
# Document:  The
# Sustainability website also provides examples of how our
# responsible management philosophy is implemented within
# our business and throughout the Power Corporation group of companies
# Document:
# We provide information on our ESG progress to a number
# of stakeholders and participate in the annual CDP
# Climate Change program, supporting the organization’s
# endeavours to increase transparency and disclosure on climate change
# Document:  Our CDP submission is available on the
# Climate Change page of our Sustainability website
# Document:
# The Governance section of our corporate website
# also contains detailed information on our corporate
# governance practices
# Document:
# As signatory to the United Nations Global Compact (UNGC),
# we submit a Communication on Progress annually as part
# of our commitment of support to the UNGC's ten universal
# principles on human rights, labour, environment and
# anti-corruption
# Document: Abbreviations
# The following abbreviations are used throughout this document:
# C$ (Canadian dollars); ESG (Environment, Social, Governance);
# Great-West Lifeco (Great-West Lifeco Inc
# Document: ); GHG (greenhouse gas);
# IGM Financial (IGM Financial Inc
# Document: ); MWh (megawatt hours); Power
# Corporation or the Corporation (Power Corporation of Canada);
# Power Financial (Power Financial Corporation); tCO2e
# (metric tonnes of CO2 equivalent)
# Document: 2021 ESG Data Supplement
# 2021 ESG Data Supplement
# For more information on our sustainability approach
# and achievements, as well as to view how our reporting has evolved over the years, please visit our Sustainability website
# Document:
# For questions related to the content of this document
# or Power Corporation's sustainability approach, please contact us at sustainability@powercorp
# Document: com
# Document: 2021 ESG DATA SUPPLEMENT › P0WER CORPORATION OF CANADA3/22
# Social Environment Governance ESG Index 2021 ESG Data Supplement
# Governance
# Topic Metric 2021 2020 2019 2018SASB
# IndicatorGRI
# IndicatorWEF
# IndicatorUNGC
# IndicatorTCFD
# Indicator
# BOARD COMPOSITION  (a)
# Board Directors  (c) Number 14 13 12 12 
# Executive Board Members Number 1 1 3 3 102-22 
# Non-Executive Board Members Number 13 12 9 9 102-22 
# Board Gender Diversity
# Women Directors  (c) Number 3 2 2 2 102-22  
# Percentage 21% 15% 17% 17% FN-AC-330a
# Document: 1 102-22,
# 405-1 
# Board Age DiversityBetween 30 and 49 (inclusive)
# Number 0 0 1 1 405-1 
# Between 50 and 70 (inclusive) Number 11 10 8 8 405-1 
# 71 and over Number 3 3 3 3 405-1 
# Board Tenure  (b) Average Years 12 12 14 13 102-22 
# Independent Board Members Number 11 10 9 9 102-22 
# Board Independence  (c) Percentage 79% 77% 75% 75% 102-22 
# Audit Committee Independence Percentage 100% 100% 100% 100% 102-22 
# Related Party and Conduct
# Review Committee IndependencePercentage 100% 100% 100% 100% 102-22 
# Human Resources Committee Independence Percentage 100% 100% 100% 100% 102-22 
# Governance and Nominating
# Committee Independence  (d)Percentage 60% 60% 60% 60% 102-22 
# Average Board and Committee
# Meeting Attendance Rate  (a)Percentage 99% 100% 97% 96%
# Directors with 4 or less mandates  (e) Percentage 100% 100% 100% 100% 102-22
# ANTI-CORRUPTION
# Operations assessed for risks related to corruption Percentage 100% 100% 100% 100% 205-1 
# Employees having received training
# on anti-corruption  (f)Percentage 100% 100% 100% 100% 205-2  
# Incidents of corruption Number 0 0 0 0 FN-AC-510a
# Document: 1 205-3  Governance2021 ESG DATA SUPPLEMENT › P0WER CORPORATION OF CANADA4/22
# Social Environment Governance ESG Index 2021 ESG Data Supplement
# Governance  (continued)
# Topic Metric 2021 2020 2019 2018SASB
# IndicatorGRI
# IndicatorWEF
# IndicatorUNGC
# IndicatorTCFD
# Indicator
# AUDITOR’S FEES  (g)
# Audit fees C$ 1,534,000 1,085,000 1,009,000 1,081,000
# Audit-related fees C$ 153,000 147,000 100,000 118,000
# Tax fees C$ 693,000 209,000 534,000 607,000
# All other fees C$ – 0 34,000 100,000
# Fees paid to external auditors for services
# other than the statutory auditPercentage 29% 15% 34% 37%
# POLITICAL CONTRIBUTIONS
# Amount of political contributions C$ 0 0 0 0 415-1
# Footnotes/Methodology
# a
# Document:  All Boar d Composition data is as of the dates of the annual meeting in the respective years, except for
# the Average Board and Committee Meeting Attendance Rates which are as of December 31
# Document:
# b
# Document:  T he Corporation believes that continuity of membership is critical to its Board’s efficient operation and
# accordingly has not adopted policies imposing an arbitrary term or retirement age limit for its Directors
# Document:
# Such limits fail to take into account the special characteristics of issuers such as Power Corporation and
# its group companies, which operate in a highly complex and technical environment
# Document:  In such a context, the
# Corporation believes that a lengthy Board tenure, not limited by arbitrary determinations, is vital to
# the Directors’ understanding of the Corporation’s diverse businesses and those of its group companies,
# and to their bringing a substantive contribution to the Board
# Document:
# c
# Document:  As a t December 31, 2021, there were three women sitting on the Corporation's Board of Directors,
# representing 21% of the Board members
# Document:  On May 12, 2022, subsequent to year-end, four women were
# elected to the Board at the 2022 Annual Meeting of Shareholders, bringing the percentage of women on
# the Board to 29%
# Document:  Within the meaning of the Canadian Securities Administrators (CSA) Guidelines and National Instrument 52-110 – Audit Committees  and National Instrument 58-101 – Disclosure of Corporate
# Governance Practices  (the instruments) and in the Board’s view, the following eleven Directors (constituting
# more than 75% of the Board), namely Pierre Beaudoin, Marcel R
# Document:  Coutu, Gary A
# Document:  Doer, Anthony R
# Document:  Graham,
# Sharon MacLeod, Paula Madoff, Isabelle Marcoux, Christian Noyer, T
# Document:  Timothy Ryan, Jr
# Document: , Siim A
# Document:  Vanaselja
# and Elizabeth D
# Document:  Wilson, are independent and have no other relationships that could reasonably interfere
# with the exercise of their independent judgment in discharging their duties to the Corporation
# Document:
#  P aul Desmarais, Jr
# Document: , Chairman, and André Desmarais, Deputy Chairman, being former executive officers
# of the Corporation within the past three years, are not independent
# Document:  R
# Document:  Jeffrey Orr, President and CEO, being an executive officer of the Corporation, is not independent
# Document:  F or more information on our definition of independence, please refer to the  Independence of Directors
# section of the Corporate Governance page of our corporate website
# Document:
# d
# Document:  F ollowing the retirement of Paul Desmarais, Jr
# Document:  and André Desmarais from their executive roles as Co-Chief
# Executive Officers of the Corporation on February 13, 2020, the Governance and Nominating Committee
# is now entirely composed of Directors who are not members of management of the Corporation
# Document:
# e
# Document:  R epresents mandates on public company boards outside Power Corporation and its subsidiaries (including
# Great-West Lifeco and IGM Financial)
# Document:
# f
# Document:  W e communicate our anti-corruption commitments through our Code of Business Conduct and Ethics
# Document:
# We also provide formal training on our Anti-Bribery Policy Statement  and supporting Global Policy
# Document:  To
# maintain awareness, we send our personnel periodic reminders of their duties and responsibilities under
# the policy
# Document:  We also require all our Directors, officers and employees to certify their compliance with the policy at least annually by attesting their compliance with our Code of Business Conduct and Ethics
# Document:
# g
# Document:  T he Auditor’s fees are disclosed in the Corporation’s Annual Information Form available in the Investors -
# Shareholder Reports section of our corporate website
# Document:  The Auditor’s fees exclude fees paid by Power
# Financial, Great-West Lifeco, IGM Financial and certain other subsidiary entities
# Document: Governance2021 ESG DATA SUPPLEMENT › P0WER CORPORATION OF CANADA5/22
# Social Environment Governance ESG Index 2021 ESG Data Supplement
# Environment  (a)
# Topic MetricThird
# Party
# Verified* 2021 2020 2019 20182013  (c)
# (Base Year)SASB
# IndicatorGRI
# IndicatorWEF
# IndicatorUNGC
# IndicatorTCFD
# Indicator
# GHG EMISSIONS  (b)   
# GHG Emissions (Scope 1, 2 and 3)  (c) tCO2e 45%  98,142 103,085 136,247 135,446 155,459   
# GHG Emissions (Scope 1 and 2) tCO2e 100% 24,826 28,188 42,582 39,935 52,685   
# Direct (Scope 1) GHG emissions  (d) tCO2e 100%  9,751 9,648 18,526 17,013 21,000 305-1   
# Indirect (Scope 2) GHG emissions  (e) tCO2e 100%  15,075 18,540 24,057 22,922 31,685 305-2   
# Other Indirect GHG Emissions (Scope 3) tCO2e  26% 73,316 74,897 93,665 95,511 102,774 305-3   
# Business travel tCO2e 6%  1,411 2,613 14,230 15,400 11,883 305-3   
# Waste generated in operations tCO2e 87%  740 877 1,722 1,507 2,675 305-3   
# Upstream transportation and distribution of
# water to corporate officestCO2e  100% 43 79 109 101 165 305-3   
# Purchased goods and services (paper) tCO2e 0%  2,667 3,161 2,538 5,362 – 305-3   
# Upstream leased assets tCO2e 0% 8,320 9,027 10,644 11,108 15,614 305-3   
# Investments  (f) tCO2e 30%  60,136 59,140 64,422 62,034 72,436 305-3   
# GHG Emission Intensity  (g) 305-4  
# GHG intensity by revenue tCO2e per
# C$100,000
# of revenue  0
# Document: 038 0
# Document: 044 0
# Document: 087 0
# Document: 083 0
# Document: 178 305-4
# GHG intensity by full-time employee tCO2e per
# full-time
# employee  0
# Document: 82 1
# Document: 04 1
# Document: 60 1
# Document: 51 2
# Document: 30 305-4  
# GHG intensity by square footage tCO2e per
# 1,000 square
# feet  4
# Document: 39 4
# Document: 92 7
# Document: 44 6
# Document: 96 9
# Document: 13 305-4  
# GHG Emissions Performance  (h)
# Year-over-year variation Percentage   -4
# Document: 6% -23
# Document: 9% 0
# Document: 9% -5
# Document: 6% – Environment
# * Da ta has been third party verified to a limited level of assurance covering the 2021 calendar year only
# Document:  Where less than 100% of the data has been verified, the percentages were calculated from verified data covering
# Power Corporation, Great-West Lifeco and IGM Financial
# Document: 2021 ESG DATA SUPPLEMENT › P0WER CORPORATION OF CANADA6/22
# Social Environment Governance ESG Index 2021 ESG Data Supplement
# Environment  (a) (continued)
# Topic Metric 2021 2020 2019 20182013  (c)
# (Base Year)SASB
# IndicatorGRI
# IndicatorWEF
# IndicatorUNGC
# IndicatorTCFD
# Indicator
# ENERGY
# Energy Consumed Within the Group  (i) MWh 123,420 138,827 183,610 181,182 207,285 302-1 
# Direct energy  (j) MWh 46,902 48,771 80,306 79,283 92,904 302-1 
# Renewable direct energy  (k) Percentage 5
# Document: 1% 7
# Document: 0% 6
# Document: 4% 7
# Document: 4% 0% 302-1 
# Indirect energy  (l) MWh 76,519 90,056 103,304 101,899 114,381 302-1 
# Renewable indirect energy  (m) Percentage 60
# Document: 1% 58
# Document: 0% 57
# Document: 5% 58
# Document: 5% 55
# Document: 5% 302-1 
# Energy Consumed Outside the Group  (i) MWh 477,728 486,852 517,833 522,661 544,835 302-2 
# Direct energy  (j) MWh 206,585 206,043 217,915 211,400 205,568 302-2 
# Renewable direct energy  (k) Percentage 1
# Document: 9% 1
# Document: 4% 0
# Document: 5% 0
# Document: 4% 0% 302-2 
# Indirect energy  (l) MWh 271,143 280,809 299,918 311,261 339,267 302-2 
# Renewable indirect energy  (m) Percentage 84
# Document: 7% 85
# Document: 5% 85
# Document: 8% 87
# Document: 0% 87
# Document: 9% 302-2 
# Energy Intensity  (n) 302-3
# Energy intensity by revenue MWh per
# C$100,000
# of revenue0
# Document: 191 0
# Document: 215 0
# Document: 376 0
# Document: 377 0
# Document: 699 302-3 
# Energy intensity by full-time employee MWh per
# full-time
# employee4
# Document: 10 5
# Document: 10 6
# Document: 91 6
# Document: 87 9
# Document: 04 302-3 
# Energy intensity by square footage MWh per
# 1,000 square
# feet21
# Document: 83 24
# Document: 24 32
# Document: 06 31
# Document: 59 35
# Document: 90 302-3 Environment

# %%
anonymized_documents
# Out:
# ['2021\nESG Data \nSupplement2021 ESG DATA SUPPLEMENT\u2002›\u2002P0WER CORPORATION OF CANADA2/22\nSocial Environment Governance ESG Index 2021 ESG Data Supplement\nAt Power Corporation, we are committed \nto continuously enhancing our \nEnvironmental, Social and Governance \n(ESG) reporting',
#  ' \nThis document provides quantitative \ninformation on our ESG achievements, \nand\xa0is intended to supplement \nthe information available on our \nSustainability\xa0website',
#  'Reporting Scope\nThe content of this ESG data supplement has been \ninformed by stakeholder requests, as well as international \nstandards on ESG reporting, including the Global \nReporting Initiative (GRI) Standards, Sustainability \nAccounting Standards Board (SASB), the World Economic \nForum (WEF) “Measuring Stakeholder Capitalism: Towards \nCommon Metrics and Consistent Reporting of Sustainable \nValue Creation”, and the Task Force on Climate-related \nFinancial Disclosures (TCFD) Recommendations',
#  ' The \ndata is reported annually, for the calendar years ended \nDecember\xa031, unless otherwise indicated',
#  '\nEnvironment: Our environmental data includes the data \nof our publicly traded operating companies Great-West \nLifeco and IGM Financial, as well as that of our wholly \nowned subsidiary Square Victoria Real Estate',
#  '\nSocial: Power Corporation’s employee data is consolidated \nbased on the definition of financial control and therefore \nincludes the data of our publicly traded operating companies \nGreat -W est Lifeco and IGM\xa0Financial, as well as the data of \nthe Corporation’s wholly owned or controlled subsidiaries',
#  '\nGovernance: Our governance data pertains to \nPower\xa0Corporation',
#  'External Assessment\nWe are committed to ensuring the quality and integrity \nof the data we report',
#  ' To date, our environmental \ndata related to GHG emissions have been verified by \nPricewaterhouseCoopers (PwC) to a limited level of \nassurance in accordance with the International Standard \non Assurance Engagements 3410, Assurance Engagements \non Greenhouse Gas Statements (ISAE 3410)',
#  '\nAdditional Information Sources\nFor additional information, readers are referred \nto\xa0our\xa0Sustainability website where we publicly disclose \nour\xa0sustainability policies, commitments and initiatives',
#  ' The \nSustainability website also provides examples of how\xa0our \nresponsible management philosophy is implemented within \nour business and throughout the Power Corporation group of\xa0companies',
#  '\nWe provide information on our ESG progress to a number \nof stakeholders and participate in the annual CDP \nClimate Change program, supporting the organization’s \nendeavours to increase transparency and disclosure on climate change',
#  ' Our CDP submission is available on the \nClimate Change page of our Sustainability\xa0website',
#  '\nThe Governance section of our corporate website \nalso contains detailed information on our corporate \ngovernance practices',
#  "\nAs signatory to the United Nations Global Compact (UNGC), \nwe\xa0submit a Communication on Progress annually as part \nof our commitment of support to the UNGC's ten universal \nprinciples on human rights, labour, environment and \nanti-corruption",
#  'Abbreviations\nThe following abbreviations are used throughout this document: \nC$\xa0(Canadian dollars); ESG\xa0(Environment, Social, Governance); \nGreat-West Lifeco (Great-West Lifeco\xa0Inc',
#  '); GHG (greenhouse gas); \nIGM Financial (IGM\xa0Financial\xa0Inc',
#  '); MWh (megawatt hours); Power \nCorporation or\xa0the Corporation (Power Corporation of Canada);  \nPower Financial (Power Financial Corporation); tCO2e  \n(metric tonnes of CO2\xa0equivalent)',
#  '2021 ESG Data Supplement\n2021 ESG Data Supplement\nFor more information on our sustainability approach \nand achievements, as well as to view how our reporting has evolved over the years, please visit our\xa0Sustainability website',
#  "\nFor questions related to the content of this document \nor Power Corporation's sustainability approach, please\xa0contact us at sustainability@powercorp",
#  'com',
#  '2021 ESG DATA SUPPLEMENT\u2002›\u2002P0WER CORPORATION OF CANADA3/22\nSocial Environment Governance ESG Index 2021 ESG Data Supplement\nGovernance\nTopic Metric 2021 2020 2019 2018SASB \nIndicatorGRI \nIndicatorWEF \nIndicatorUNGC \nIndicatorTCFD \nIndicator\nBOARD COMPOSITION  (a)\nBoard Directors  (c) Number 14 13 12 12 \uf06c\nExecutive Board Members Number 1 1 3 3 102-22 \uf06c\nNon-Executive Board Members Number 13 12 9 9 102-22 \uf06c\nBoard Gender Diversity\nWomen Directors  (c) Number 3 2 2 2 102-22 \uf06c \uf06c\nPercentage 21% 15% 17% 17% FN-AC-330a',
#  '1 102-22, \n405-1\uf06c \uf06c\nBoard Age DiversityBetween 30\xa0and 49 (inclusive)\nNumber 0 0 1 1 405-1 \uf06c\nBetween 50\xa0and 70 (inclusive) Number 11 10 8 8 405-1 \uf06c\n71 and over Number 3 3 3 3 405-1 \uf06c\nBoard Tenure  (b) Average Years 12 12 14 13 102-22 \uf06c\nIndependent Board Members Number 11 10 9 9 102-22 \uf06c\nBoard Independence  (c) Percentage 79% 77% 75% 75% 102-22 \uf06c\nAudit Committee Independence Percentage 100% 100% 100% 100% 102-22 \uf06c\nRelated Party and Conduct  \nReview Committee IndependencePercentage 100% 100% 100% 100% 102-22 \uf06c\nHuman Resources Committee Independence Percentage 100% 100% 100% 100% 102-22 \uf06c\nGovernance and Nominating  \nCommittee Independence  (d)Percentage 60% 60% 60% 60% 102-22 \uf06c\nAverage Board and Committee  \nMeeting Attendance Rate  (a)Percentage 99% 100% 97% 96%\nDirectors with 4\xa0or less mandates  (e) Percentage 100% 100% 100% 100% 102-22\nANTI-CORRUPTION\nOperations assessed for risks related to corruption Percentage 100% 100% 100% 100% 205-1 \uf06c\nEmployees having received training  \non anti-corruption  (f)Percentage 100% 100% 100% 100% 205-2 \uf06c \uf06c\nIncidents of corruption Number 0 0 0 0 FN-AC-510a',
#  '1 205-3 \uf06c \uf06cGovernance2021 ESG DATA SUPPLEMENT\u2002›\u2002P0WER CORPORATION OF CANADA4/22\nSocial Environment Governance ESG Index 2021 ESG Data Supplement\nGovernance  (continued)\nTopic Metric 2021 2020 2019 2018SASB \nIndicatorGRI \nIndicatorWEF \nIndicatorUNGC \nIndicatorTCFD \nIndicator\nAUDITOR’S FEES  (g)\nAudit fees C$ 1,534,000 1,085,000 1,009,000 1,081,000\nAudit-related fees C$ 153,000 147,000 100,000 118,000\nTax fees C$ 693,000 209,000 534,000 607,000\nAll other fees C$ – 0 34,000 100,000\nFees paid to external auditors for services  \nother than the statutory auditPercentage 29% 15% 34% 37%\nPOLITICAL CONTRIBUTIONS\nAmount of political contributions C$ 0 0 0 0 415-1\nFootnotes/Methodology\na',
#  ' All Boar d Composition data is as of the dates of the annual meeting in the respective years, except for \nthe Average Board and Committee Meeting Attendance Rates which are as of December\xa031',
#  '\nb',
#  ' T he Corporation believes that continuity of membership is critical to its Board’s efficient operation and \naccordingly has not adopted policies imposing an arbitrary term or retirement age limit for its Directors',
#  ' \nSuch limits fail to take into account the special characteristics of issuers such as Power Corporation and \nits group companies, which operate in a highly complex and technical environment',
#  ' In such a context,\xa0the \nCorporation believes that a lengthy Board tenure, not limited by arbitrary determinations, is vital to \nthe\xa0Directors’ understanding of the Corporation’s diverse businesses and those of its group companies, \nand to their bringing a substantive contribution to the Board',
#  '\nc',
#  " As a t December 31, 2021, there were three women sitting on the Corporation's Board of Directors, \nrepresenting 21% of the Board members",
#  ' On May 12, 2022, subsequent to year-end, four women were \nelected to the Board at the 2022 Annual Meeting of Shareholders, bringing the percentage of women on \nthe Board to 29%',
#  ' Within the meaning of the Canadian Securities Administrators (CSA) Guidelines and National Instrument 52-110\u2009–\u2009Audit Committees  and National Instrument 58-101\u2009–\u2009Disclosure of Corporate \nGovernance Practices  (the instruments) and in the Board’s view, the following eleven Directors (constituting \nmore than 75% of the Board), namely Pierre Beaudoin, Marcel R',
#  ' Coutu, Gary A',
#  ' Doer, Anthony R',
#  ' Graham, \nSharon MacLeod, Paula Madoff, Isabelle Marcoux, Christian Noyer, T',
#  ' Timothy Ryan,\xa0Jr',
#  ', Siim A',
#  ' Vanaselja \nand Elizabeth D',
#  ' Wilson, are\xa0independent and have no other relationships that could reasonably interfere \nwith the exercise of their independent judgment in discharging their duties to the Corporation',
#  '\n P aul Desmarais,\xa0Jr',
#  ', Chairman, and André Desmarais, Deputy Chairman, being former executive officers \nof the Corporation within the past three years, are not independent',
#  ' R',
#  ' Jeffrey Orr, President and CEO, being an executive officer of the Corporation, is not independent',
#  ' F or more information on our definition of independence, please refer to the \u2009Independence of Directors \nsection of the Corporate Governance page of our corporate website',
#  '\nd',
#  ' F ollowing the retirement of Paul Desmarais,\xa0Jr',
#  ' and André Desmarais from their executive roles as Co-Chief \nExecutive Officers of the Corporation on February\xa013, 2020, the Governance and Nominating Committee \nis now entirely composed of Directors who are not members of management of the Corporation',
#  '\ne',
#  ' R epresents mandates on public company boards outside Power Corporation and its subsidiaries (including \nGreat-West Lifeco and IGM Financial)',
#  '\nf',
#  ' W e communicate our anti-corruption commitments through our Code of Business Conduct and Ethics ',
#  ' \nWe also provide formal training on our Anti-Bribery Policy Statement  and supporting Global Policy ',
#  ' To \nmaintain awareness, we send our personnel periodic reminders of their duties and responsibilities under \nthe policy',
#  ' We also require all our Directors, officers and employees to certify their compliance with the policy at least annually by attesting their compliance with our Code of Business Conduct and Ethics',
#  '\ng',
#  ' T he Auditor’s fees are disclosed in the Corporation’s Annual Information Form available in the Investors\xa0- \nShareholder Reports section of our corporate website',
#  ' The Auditor’s fees exclude fees paid by Power \nFinancial, Great-West Lifeco, IGM Financial and certain other subsidiary entities',
#  'Governance2021 ESG DATA SUPPLEMENT\u2002›\u2002P0WER CORPORATION OF CANADA5/22\nSocial Environment Governance ESG Index 2021 ESG Data Supplement\nEnvironment  (a)\nTopic MetricThird  \nParty\nVerified* 2021 2020 2019 20182013\u2009 (c)\n(Base Year)SASB \nIndicatorGRI \nIndicatorWEF \nIndicatorUNGC \nIndicatorTCFD \nIndicator\nGHG EMISSIONS  (b) \uf06c \uf06c \uf06c\nGHG Emissions (Scope 1, 2 and 3)  (c) tCO2e 45%\u2003 98,142 103,085 136,247 135,446 155,459 \uf06c \uf06c \uf06c\nGHG Emissions (Scope 1 and 2) tCO2e 100% 24,826 28,188 42,582 39,935 52,685 \uf06c \uf06c \uf06c\nDirect (Scope 1) GHG emissions  (d) tCO2e 100%\u2003 9,751 9,648 18,526 17,013 21,000 305-1 \uf06c \uf06c \uf06c\nIndirect (Scope 2) GHG emissions  (e) tCO2e 100%\u2003 15,075 18,540 24,057 22,922 31,685 305-2 \uf06c \uf06c \uf06c\nOther Indirect GHG Emissions (Scope 3) tCO2e \u200326% 73,316 74,897 93,665 95,511 102,774 305-3 \uf06c \uf06c \uf06c\nBusiness travel tCO2e 6%\u2003 1,411 2,613 14,230 15,400 11,883 305-3 \uf06c \uf06c \uf06c\nWaste generated in operations tCO2e 87%\u2003 740 877 1,722 1,507 2,675 305-3 \uf06c \uf06c \uf06c\nUpstream transportation and distribution of \nwater to corporate officestCO2e \u2003100% 43 79 109 101 165 305-3 \uf06c \uf06c \uf06c\nPurchased goods and services (paper) tCO2e 0%\u2003 2,667 3,161 2,538 5,362 – 305-3 \uf06c \uf06c \uf06c\nUpstream leased assets tCO2e 0% 8,320 9,027 10,644 11,108 15,614 305-3 \uf06c \uf06c \uf06c\nInvestments  (f) tCO2e 30%\u2003 60,136 59,140 64,422 62,034 72,436 305-3 \uf06c \uf06c \uf06c\nGHG Emission Intensity  (g) 305-4 \uf06c \uf06c\nGHG intensity by revenue tCO2e per \nC$100,000  \nof revenue\u2003 0',
#  '038 0',
#  '044 0',
#  '087 0',
#  '083 0',
#  '178 305-4\nGHG intensity by full-time employee tCO2e per \nfull-time  \nemployee\u2003 0',
#  '82 1',
#  '04 1',
#  '60 1',
#  '51 2',
#  '30 305-4 \uf06c \uf06c\nGHG intensity by square footage tCO2e per \n1,000 square \nfeet\u2003 4',
#  '39 4',
#  '92 7',
#  '44 6',
#  '96 9',
#  '13 305-4 \uf06c \uf06c\nGHG Emissions Performance  (h)\nYear-over-year variation Percentage \u2003 -4',
#  '6% -23',
#  '9% 0',
#  '9% -5',
#  '6% – \uf06cEnvironment\n* Da ta has been third party verified to a limited level of assurance covering the 2021 calendar year only',
#  ' Where less than 100% of the data has been verified, the percentages were calculated from verified data covering \nPower Corporation, Great-West Lifeco and IGM Financial',
#  '2021 ESG DATA SUPPLEMENT\u2002›\u2002P0WER CORPORATION OF CANADA6/22\nSocial Environment Governance ESG Index 2021 ESG Data Supplement\nEnvironment  (a) (continued)\nTopic Metric 2021 2020 2019 20182013 \u2009(c)\n(Base Year)SASB \nIndicatorGRI \nIndicatorWEF \nIndicatorUNGC \nIndicatorTCFD \nIndicator\nENERGY\nEnergy Consumed Within the Group  (i) MWh 123,420 138,827 183,610 181,182 207,285 302-1 \uf06c\nDirect energy  (j) MWh 46,902 48,771 80,306 79,283 92,904 302-1 \uf06c\nRenewable direct energy  (k) Percentage 5',
#  '1% 7',
#  '0% 6',
#  '4% 7',
#  '4% 0% 302-1 \uf06c\nIndirect energy  (l) MWh 76,519 90,056 103,304 101,899 114,381 302-1 \uf06c\nRenewable indirect energy  (m) Percentage 60',
#  '1% 58',
#  '0% 57',
#  '5% 58',
#  '5% 55',
#  '5% 302-1 \uf06c\nEnergy Consumed Outside the Group  (i) MWh 477,728 486,852 517,833 522,661 544,835 302-2 \uf06c\nDirect energy  (j) MWh 206,585 206,043 217,915 211,400 205,568 302-2 \uf06c\nRenewable direct energy  (k) Percentage 1',
#  '9% 1',
#  '4% 0',
#  '5% 0',
#  '4% 0% 302-2 \uf06c\nIndirect energy  (l) MWh 271,143 280,809 299,918 311,261 339,267 302-2 \uf06c\nRenewable indirect energy  (m) Percentage 84',
#  '7% 85',
#  '5% 85',
#  '8% 87',
#  '0% 87',
#  '9% 302-2 \uf06c\nEnergy Intensity  (n) 302-3\nEnergy intensity by revenue MWh per \nC$100,000  \nof revenue0',
#  '191 0',
#  '215 0',
#  '376 0',
#  '377 0',
#  '699 302-3 \uf06c\nEnergy intensity by full-time employee MWh per  \nfull-time \nemployee4',
#  '10 5',
#  '10 6',
#  '91 6',
#  '87 9',
#  '04 302-3 \uf06c\nEnergy intensity by square footage MWh per  \n1,000 square \nfeet21',
#  '83 24',
#  '24 32',
#  '06 31',
#  '59 35',
#  '90 302-3 \uf06cEnvironment']

# %%
pdf_file_path = os.path.join(os.getcwd(), 'smol.pdf')
pdf_text = parse_pdf(pdf_file_path)
document_contents = pdf_text.split(".")
project_name="esg-rag"
equo = equonode(project_name)
db = equonode(None)

# %%
# Try doing the RAG with anonymized data 
import time 
anonymized_contents = []
entities = {}
person_count=0
org_count=0
location_count=0

for doc in document_contents:
    if len(entities) > 0:
        doc = track_entities(doc, entities)
    
    result =  anonymize(doc, entities, person_count, org_count, location_count)
    # Update counts for everything else
    person_count = result["num_persons"]
    org_count = result["num_orgs"], 
    location_count = result["num_locations"]
    entities = result["entities"]
    # Identify already known entities, keep track of which is which 
    anonymized_contents.append(anonymized_doc)

document_contents = anonymized_contents[:]
document_contents[:10]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# ~/anaconda3/lib/python3.9/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# ~/anaconda3/lib/python3.9/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# ~/anaconda3/lib/python3.9/site-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     415                 idx += 3
# --> 416         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_10575/327977788.py in <module>
#      11         doc = track_entities(doc, entities)
#      12
# ---> 13     result =  anonymize(doc, entities, person_count, org_count, location_count)
#      14     # Update counts for everything else
#      15 #     person_count = result["num_persons"]
#
# /tmp/ipykernel_10575/2548929154.py in anonymize(text, entities, person_count, org_count, location_count)
#     122                         }
#     123     })
# --> 124     return r.json()
#     125
#     126 result = anonymize("Roger and Donald both work for Acme Inc. Their father worked at IBM.")
#
# ~/anaconda3/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     976             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     979
#     980     @property
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)

# %%
model = SentenceTransformer("sentence-transformers/multi-qa-MiniLM-L6-cos-v1")



#Obtain embeddings and convert from ndarray to Python list. 
#Make sure that your embeddings are a list of floating point values before uploading
embeddings = model.encode(document_contents)
# embeddings = embeddings.tolist()
 
project_name='esg-report:power-corporation'

# %%
query = 'How has the leadership of the corporation changed since Paul Desmarais stepped down?'

pipeline = RAGPipeline()

# pipeline.process(query, document_contents)
# context = pipeline.retrieve()

# answer = query_with_ollama(f"Article: {context} \n Answer the following question using the article provided: {query}",
#                  is_verbose=False)

answer = pipeline.run(query, document_contents)

# %%
# query = 'What people have historically inhabited the nation of Kazakhstan?'
query = 'How has the leadership of the corporation changed since Paul Desmarais stepped down?'
query = model.encode(query)#.tolist()
 
context_text = "".join([obj["text"] for obj in pipeline.context][:10])
snippets = context_text.split(".")
context = pipeline.model.encode(snippets).tolist()

(best_document, highest_similarity, dp) = db.dynamic_retrieval(
                                            query, 
                                            context, 
                                            snippets, 
                                            optimized=False,
                                            threshold=0.0
                                        )

# %%
best_document, highest_similarity
# Out:
# (" and André Desmarais from their executive roles as Co-Chief \nExecutive Officers of the Corporation on February\xa013, 2020, the Governance and Nominating Committee \nis now entirely composed of Directors who are not members of management of the Corporation F ollowing the retirement of Paul Desmarais,\xa0Jr, Chairman, and André Desmarais, Deputy Chairman, being former executive officers \nof the Corporation within the past three years, are not independent T he Corporation believes that continuity of membership is critical to its Board’s efficient operation and \naccordingly has not adopted policies imposing an arbitrary term or retirement age limit for its Directors In such a context,\xa0the \nCorporation believes that a lengthy Board tenure, not limited by arbitrary determinations, is vital to \nthe\xa0Directors’ understanding of the Corporation’s diverse businesses and those of its group companies, \nand to their bringing a substantive contribution to the Board The \nSustainability website also provides examples of how\xa0our \nresponsible management philosophy is implemented within \nour business and throughout the Power Corporation group of\xa0companies Jeffrey Orr, President and CEO, being an executive officer of the Corporation, is not independent Within the meaning of the Canadian Securities Administrators (CSA) Guidelines and National Instrument 52-110\u2009–\u2009Audit Committees  and National Instrument 58-101\u2009–\u2009Disclosure of Corporate \nGovernance Practices  (the instruments) and in the Board’s view, the following eleven Directors (constituting \nmore than 75% of the Board), namely Pierre Beaudoin, Marcel R As a t December 31, 2021, there were three women sitting on the Corporation's Board of Directors, \nrepresenting 21% of the Board members\n P aul Desmarais,\xa0Jr",
#  0.5397035344308806)

# %% [markdown]
# ### Anonymization API Demo
#
# #### Here, we are going to keep track of a handful of documents, anonymize their contents,
# #### and keep track of names entities along the way.
# ###

# %%
def anonymize(text: str, entities={}, person_count=0, org_count=0, location_count=0) -> str:
    """
    Anonymize your documents using our API for data protection!
    API keys will become available for anyone signing up here:

    https://equo.ai/signup
    """
    r = requests.post("https://api-equo-ai.tail44cf99.ts.net/protect/",
                      json={
                            "text":text,
                            "access_token":"abdefg", 
                            "entities":entities,
                            "item_counts":{
                                "person_count":person_count,
                                "org_count":org_count,
                                "location_count":location_count
                        }
    })
    return r.json()



def track_entities(doc, entities):
    """
    Keep track of previously 
    seen named entities 
    """
    for ent in list(entities.keys()):
    #     print(result["entities"][ent])
        try:
            category = entities[ent]
            doc = doc.replace(ent, category)
        except Exception as e:
            print(e)
    # print(list(result["entities"].keys()))
    return doc 

result = anonymize("Roger and Donald both work for Acme Inc. Their father worked at IBM.")

person_count = result["num_persons"] 
org_count = result["num_orgs"], 
location_count = result["num_locations"]

q2 = "David and Roger are brothers."
print(result["entities"])
entities = result["entities"]

q2 = track_entities(q2, entities)
next_result = anonymize(q2, entities, person_count, org_count, location_count)
print(next_result["text"])
# Out:
# {'Roger': '<PERSON 1>', 'Donald': '<PERSON 2>', 'Acme Inc.': '<ORGANIZATION 1>', 'IBM': '<ORGANIZATION 2>'}
# <PERSON 3> and <PERSON 1> are brothers.

# %%
entities = {}
person_count = 0
org_count = 0
location_count = 0
anonymized_documents = []

documents = [
    "David and Roger are brothers. Devin is their cousin",
    "Roger and Donald both work for Acme Inc. Their father worked at IBM.",
    "Donald and David are actually best friends. Sometimes they hang out with Roger.",
    "David and Roger are brothers",
    "Donald and Roger sometimes hang out.",
    "David does not talk to his cousin"

]

for i, doc in enumerate(documents):
    try:
        doc = track_entities(doc, entities)
        result = anonymize(doc, entities, person_count, org_count, location_count)
        person_count = result["num_persons"] 
        org_count = result["num_orgs"], 
        location_count = result["num_locations"]
        entities = result["entities"]
        if i > 1:
            anonymized_documents.append(doc)
        print(f'Document: {doc}')
    except Exception as e:
        print(e)
# Out:
# Document: David and Roger are brothers. Devin is their cousin
# Expecting value: line 2 column 1 (char 1)
# Document: Donald and <PERSON 1> are actually best friends. Sometimes they hang out with <PERSON 2>.
# Document: <PERSON 1> and <PERSON 2> are brothers
# Document: <PERSON 4> and <PERSON 2> sometimes hang out.
# Document: <PERSON 1> does not talk to his cousin

# %%
context = "".join(anonymized_documents[2:])
# context = anonymized_documents[-1]

question = "Who sometimes hang out together?"
query = f"Article: {context} \n Given the article above, answer the following question: {question}"
ans = query_with_ollama(query, is_verbose=False)

print(ans)
# Out:
# According to the article, PERSON 4 and PERSON 2 sometimes hang out together.

# %%
# Out:
# ['Donald and <PERSON 1> are actually best friends. Sometimes they hang out with <PERSON 2>.',
#  '<PERSON 1> and <PERSON 2> are brothers',
#  '<PERSON 3> and <PERSON 2> sometimes hang out']
